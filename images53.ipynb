# %%
import pandas as pd
import config_prod as config
from datetime import date, timedelta
import phood_api
import numpy as np

# %%
names = pd.read_excel('Phood Solutions List Names.xlsx')
names=names.drop([0,1,2])
names=names.iloc[:,0:2]

names.columns = ['PLU', 'Item_Names']
names.reset_index(drop=True)
ndic = names.set_index('PLU').to_dict('index')

# %%
locations = ['dedham', 'hingham', 'westford', 'westhartford', 'cranston']
unnamedplu = []
masterlist=[]
#print(ndic)
locationinfo = {51: {'name': 'Dedham'}, 52: {'name': 'Hingham'}, 53: {'name': 'Westford'}, 54: {'name': 'West hartford'}, 55: {'name': 'Cranston'}}
for location in locations:
    phoodServer = phood_api.PhoodAPI(config.base_url)
    username = location
    res = phoodServer.login(username, config.password).json()
    endDate = date.today() #- timedelta(days=date.today().weekday())
    startDate = date(2019,10, 1)
    #endDate = date.today()- timedelta(days=1)
    #startDate = endDate - timedelta(days=6)
    res = phoodServer.get_food_logs(startDate, endDate).json()
    PLUEntries = filter(lambda x: x['clientId'], res)
    orderedEntries = list(sorted(PLUEntries, key=lambda x: x["loggedTime"]))
    hotBar,saladBar,soupBar = set(),set(),set()
    res = phoodServer.getPersistentItems().json()
    for pItem in res:
        if pItem['station'].lower().startswith('hot bar'):
            hotBar.add(pItem['clientId'])
        elif pItem['station'].lower().startswith('salad bar'):
            saladBar.add(pItem['clientId'])
        elif pItem['station'].lower().startswith('soup'):
            soupBar.add(pItem['clientId'])
        else:
            print(f'unclassified item {pItem}')

    res = phoodServer.getPanInfo().json()
    panInfo = {}
    for pan in res:
        panInfo[pan["id"]] = {"name": pan["name"], "weight": pan["weightQuantity"]}
    #print(panInfo)
            
    for item in orderedEntries:
        item['clientId'] = item['clientId'].replace("-", "")
        #print(item['clientId'])
        if item['itemName'] in ndic.keys():
            item['itemName'] = ndic[int(item['clientId'])]['Item_Names']
        else:
            unnamedplu.append(item)
        #print(item['Item_Names'])
        if item['clientId'] in hotBar:
            item['station'] = 'HB'
        elif item['clientId'] in saladBar:
            item['station'] = 'SB'
        elif item['clientId'] in soupBar:
            item['station'] = 'SO'
        item['Location'] = locationinfo[item['locationId']]['name']
        item['Served']=item['Saved']=item['Sold']=item['Shrink']=0
        if 'panId' in item and item['panId']:
            panWeight = panInfo[item['panId']]['weight']
        else:
            panWeight = item['panWeight'] 
        if item['actionTaken']=='Served':
            item['Served'] = +item['quantity'] - panWeight
        if item['actionTaken']=='Discarded':
            item['Shrink'] = +item['quantity'] - panWeight
        if item['actionTaken']=='Saved':
            item['Saved'] = +item['quantity'] - panWeight
        item['Sold'] = item['Served'] - item['Saved'] - item['Shrink']
        if item['clientId'] == '00449791900':
            item['station'] = 'HB'
            #print(item)
        
    masterlist.extend(orderedEntries)

# %%
raw = pd.DataFrame(masterlist)

# %%
rawfile=raw

# %%
raw.columns = ['Date_Produced', 'Log_ID', 'Item_Name', 'Item_Type', 'PLU', 'Logged_Time', 'Meal', 'Action_Taken', 'Action_Reason', 'Quantity', 'Pan_ID', 'Pan_Weight', 'Unit', 'Station', 'Employee_Name', 'Location_ID','Location', 'Served','Saved','Sold','Shrink']

# %%
rawfile = rawfile.rename(columns={"Logged_Time": "timestamped"})
rawfile['timestamped']= pd.to_datetime(rawfile['timestamped'], utc = True)

# %%
df = rawfile[rawfile['timestamped']< '2019-11-1']
df
# Out:
#       Date_Produced  Log_ID                   Item_Name  Item_Type  \
# 0        2019-09-30   43120                  Spring Mix  Menu Item
# 1        2019-09-30   43122             Romaine Lettuce  Menu Item
# 2        2019-09-30   43123             Romaine Lettuce  Menu Item
# 3        2019-09-30   43124                Baby Spinach  Menu Item
# 4        2019-09-30   43194                   Plantains  Menu Item
# ...             ...     ...                         ...        ...
# 37600    2019-10-31   69482   Collard Greens & Tomatoes  Menu Item
# 37601    2019-10-31   69484             Chicken Tenders  Menu Item
# 37602    2019-10-31   69485                Waffle Fries  Menu Item
# 37603    2019-10-31   69486               Potato Samosa  Menu Item
# 37604    2019-10-31   69488  Buttered Chicken Meatballs  Menu Item
#
#                PLU               timestamped       Meal Action_Taken  \
# 0      46000063050 2019-10-01 06:18:52+00:00  Breakfast       Served
# 1      46000055863 2019-10-01 06:19:06+00:00  Breakfast       Served
# 2      46000055863 2019-10-01 06:19:20+00:00  Breakfast       Served
# 3      46000055923 2019-10-01 06:19:35+00:00  Breakfast       Served
# 4      46000001661 2019-10-01 07:06:17+00:00  Breakfast       Served
# ...            ...                       ...        ...          ...
# 37600  46000030030 2019-10-31 21:15:58+00:00  Breakfast    Discarded
# 37601  46000007582 2019-10-31 21:16:22+00:00  Breakfast    Discarded
# 37602  46000064878 2019-10-31 21:16:44+00:00  Breakfast    Discarded
# 37603  46000057583 2019-10-31 21:17:04+00:00  Breakfast    Discarded
# 37604  46000016160 2019-10-31 21:17:30+00:00  Breakfast    Discarded
#
#        Action_Reason  Quantity  ...  Pan_Weight  Unit Station Employee_Name  \
# 0              Start   6.45954  ...        1.94   Lbs      SB          None
# 1              Start   6.45954  ...        1.94   Lbs      SB          None
# 2              Start   6.34931  ...        1.94   Lbs      SB          None
# 3              Start   6.76819  ...        1.94   Lbs      SB          None
# 4              Start   6.74615  ...        1.94   Lbs      HB          None
# ...              ...       ...  ...         ...   ...     ...           ...
# 37600  Over Produced   5.00449  ...        0.95   Lbs      HB          None
# 37601  Over Produced   1.76370  ...        0.95   Lbs      HB          None
# 37602  Over Produced   2.55736  ...        1.90   Lbs      HB          None
# 37603  Over Produced   5.46746  ...        1.90   Lbs      HB          None
# 37604  Over Produced   4.51948  ...        0.95   Lbs      HB          None
#
#       Location_ID  Location   Served  Saved     Sold   Shrink
# 0              51    Dedham  4.51954    0.0  4.51954  0.00000
# 1              51    Dedham  4.51954    0.0  4.51954  0.00000
# 2              51    Dedham  4.40931    0.0  4.40931  0.00000
# 3              51    Dedham  4.82819    0.0  4.82819  0.00000
# 4              51    Dedham  4.80615    0.0  4.80615  0.00000
# ...           ...       ...      ...    ...      ...      ...
# 37600          55  Cranston  0.00000    0.0 -4.05449  4.05449
# 37601          55  Cranston  0.00000    0.0 -0.81370  0.81370
# 37602          55  Cranston  0.00000    0.0 -0.65736  0.65736
# 37603          55  Cranston  0.00000    0.0 -3.56746  3.56746
# 37604          55  Cranston  0.00000    0.0 -3.56948  3.56948
#
# [26042 rows x 21 columns]

# %%
images = pd.read_csv('rek-test-images-all.csv')

# %%
images
# Out:
#                         timestamp   locationId  \
# 0      2019-09-16T17:01:13.585000           51
# 1      2019-09-16T17:15:20.774000           51
# 2      2019-09-16T17:15:36.551000           51
# 3      2019-09-16T17:15:52.755000           51
# 4      2019-09-16T17:15:54.492000           51
# ...                           ...          ...
# 33757  2019-11-05T23:56:30.501000           54
# 33758  2019-11-06T00:06:43.342000           54
# 33759  2019-11-06T00:20:08.856000           55
# 33760  2019-11-06T00:22:27.407000           54
# 33761  2019-11-06T00:31:28.433000           54
#
#                                      imageId  \
# 0       96fb9610-d8a3-11e9-a35a-0de7ce4e8d91
# 1       8ff25e60-d8a5-11e9-a35a-0de7ce4e8d91
# 2       9959bf70-d8a5-11e9-a35a-0de7ce4e8d91
# 3       a3024830-d8a5-11e9-ae9b-73759b4dfb23
# 4       a40b53c0-d8a5-11e9-ae9b-73759b4dfb23
# ...                                      ...
# 33757   e346bd50-0027-11ea-90c3-45c3f76c0e47
# 33758   508edae0-0029-11ea-8246-012e5e367d18
# 33759   30ae8980-002b-11ea-8246-012e5e367d18
# 33760   8343bdf0-002b-11ea-90c3-45c3f76c0e47
# 33761   c5bdc210-002c-11ea-90c3-45c3f76c0e47
#
#                                    imageKey
# 0       51/96fb9610d8a311e9a35a0de7ce4e8d91
# 1       51/8ff25e60d8a511e9a35a0de7ce4e8d91
# 2       51/9959bf70d8a511e9a35a0de7ce4e8d91
# 3       51/a3024830d8a511e9ae9b73759b4dfb23
# 4       51/a40b53c0d8a511e9ae9b73759b4dfb23
# ...                                     ...
# 33757   54/e346bd50002711ea90c345c3f76c0e47
# 33758   54/508edae0002911ea8246012e5e367d18
# 33759   55/30ae8980002b11ea8246012e5e367d18
# 33760   54/8343bdf0002b11ea90c345c3f76c0e47
# 33761   54/c5bdc210002c11ea90c345c3f76c0e47
#
# [33762 rows x 4 columns]

# %%
images = images.rename(columns={"timestamp": "timestamped"})
images['timestamped']= pd.to_datetime(images['timestamped'], utc = True)

# %%
imagesnew = images[images['timestamped'] >= '2019-10-1']
imagesnew = imagesnew[imagesnew['timestamped'] < '2019-11-1']
imagesnew
# Out:
#                            timestamped   locationId  \
# 4035  2019-10-01 00:06:49.553000+00:00           52
# 4036  2019-10-01 00:07:02.519000+00:00           52
# 4037  2019-10-01 00:14:47.436000+00:00           53
# 4038  2019-10-01 00:18:59.163000+00:00           52
# 4039  2019-10-01 00:20:55.193000+00:00           55
# ...                                ...          ...
# 31468 2019-10-31 22:35:02.223000+00:00           53
# 31469 2019-10-31 22:35:23.892000+00:00           53
# 31470 2019-10-31 22:35:41.625000+00:00           53
# 4037    53/7a3abcc0e3e011e990c345c3f76c0e47
# 4038    52/10453ab0e3e111e990c345c3f76c0e47
# 4039    55/556e0090e3e111e98246012e5e367d18
# ...                                     ...
# 31468   53/ad91f5f0fc2e11e98246012e5e367d18
# 31469   53/ba7c6340fc2e11e98246012e5e367d18
# 31470   53/c50e3a90fc2e11e990c345c3f76c0e47
# 31471   55/6b29e140fc2f11e990c345c3f76c0e47
# 31472   54/6983e780fc3111e98246012e5e367d18
#
# [27438 rows x 4 columns]

# %%
imagesnew['year'] = imagesnew['timestamped'].dt.year
imagesnew['month'] = imagesnew['timestamped'].dt.month
imagesnew['day'] = imagesnew['timestamped'].dt.day
imagesnew['hour'] = imagesnew['timestamped'].dt.hour
imagesnew['minute'] = imagesnew['timestamped'].dt.minute
imagesnew['second'] = imagesnew['timestamped'].dt.second
#imagesnew.loc[(imagesnew.second <= 20) & (imagesnew.second > 0), "second"] = 20
#imagesnew.loc[(imagesnew.second <= 40) & (imagesnew.second > 20), "second"] = 40
#imagesnew.loc[(imagesnew.second <= 59) & (imagesnew.second > 40), "second"] = 59
#imagesnew['second'] = np.where(imagesnew['second']<=30, 30, 59)
#imagesnew = imagesnew.drop(['second'], 1)

# %%
imagesnew
# Out:
#                            timestamped   locationId  \
# 4035  2019-09-30 20:06:01.553000+00:00           52
# 4036  2019-09-30 20:06:14.519000+00:00           52
# 4037  2019-09-30 20:13:59.436000+00:00           53
# 4038  2019-09-30 20:18:11.163000+00:00           52
# 4039  2019-09-30 20:20:07.193000+00:00           55
# ...                                ...          ...
# 31468 2019-10-31 18:34:14.223000+00:00           53
# 31469 2019-10-31 18:34:35.892000+00:00           53
# 31470 2019-10-31 18:34:53.625000+00:00           53
# 31471 2019-10-31 18:39:32.308000+00:00           55
# 31472 2019-10-31 18:53:48.536000+00:00           54
#
#                                      imageId  \
# 4035    5d639410-e3df-11e9-8246-012e5e367d18
# 4036    651e0870-e3df-11e9-90c3-45c3f76c0e47
# 4037    7a3abcc0-e3e0-11e9-90c3-45c3f76c0e47
# 4038    10453ab0-e3e1-11e9-90c3-45c3f76c0e47
# 4039    556e0090-e3e1-11e9-8246-012e5e367d18
# ...                                      ...
# 31468   ad91f5f0-fc2e-11e9-8246-012e5e367d18
# 31469   ba7c6340-fc2e-11e9-8246-012e5e367d18
# 31470   c50e3a90-fc2e-11e9-90c3-45c3f76c0e47
# 31471   6b29e140-fc2f-11e9-90c3-45c3f76c0e47
# 31472   6983e780-fc31-11e9-8246-012e5e367d18
#
#                                    imageKey  year  month  day  hour  minute  \
# 4035    52/5d639410e3df11e98246012e5e367d18  2019      9   30    20       6
# 4036    52/651e0870e3df11e990c345c3f76c0e47  2019      9   30    20       6
# 4037    53/7a3abcc0e3e011e990c345c3f76c0e47  2019      9   30    20      13
# 4038    52/10453ab0e3e111e990c345c3f76c0e47  2019      9   30    20      18
# 4039    55/556e0090e3e111e98246012e5e367d18  2019      9   30    20      20
# ...                                     ...   ...    ...  ...   ...     ...
# 31468   53/ad91f5f0fc2e11e98246012e5e367d18  2019     10   31    18      34
# 31469   53/ba7c6340fc2e11e98246012e5e367d18  2019     10   31    18      34
# 31470   53/c50e3a90fc2e11e990c345c3f76c0e47  2019     10   31    18      34
# 31471   55/6b29e140fc2f11e990c345c3f76c0e47  2019     10   31    18      39
# 31472   54/6983e780fc3111e98246012e5e367d18  2019     10   31    18      53
#
#        second
# 4035        1
# 4036       14
# 4037       59
# 4038       11
# 4039        7
# ...       ...
# 31468      14
# 31469      35
# 31470      53
# 31471      32
# 31472      48
#
# [27438 rows x 10 columns]

# %%
imagesnew['logtime'] = pd.to_datetime(imagesnew[['year', 'month', 'day', 'hour', 'minute','second']])
imagesnew = imagesnew.drop(['year', 'month', 'day', 'hour', 'minute','second','timestamped'], 1)

# %%
imagesnew#.to_csv('join1.csv')
imagesnew
# Out:
#         locationId                                imageId  \
# 4035            52   5d639410-e3df-11e9-8246-012e5e367d18
# 4036            52   651e0870-e3df-11e9-90c3-45c3f76c0e47
# 4037            53   7a3abcc0-e3e0-11e9-90c3-45c3f76c0e47
# 4038            52   10453ab0-e3e1-11e9-90c3-45c3f76c0e47
# 4039            55   556e0090-e3e1-11e9-8246-012e5e367d18
# ...            ...                                    ...
# 31468           53   ad91f5f0-fc2e-11e9-8246-012e5e367d18
# 31469           53   ba7c6340-fc2e-11e9-8246-012e5e367d18
# 31470           53   c50e3a90-fc2e-11e9-90c3-45c3f76c0e47
# 31471           55   6b29e140-fc2f-11e9-90c3-45c3f76c0e47
# 31472           54   6983e780-fc31-11e9-8246-012e5e367d18
#
#                                    imageKey             logtime
# 4035    52/5d639410e3df11e98246012e5e367d18 2019-09-30 20:06:01
# 4036    52/651e0870e3df11e990c345c3f76c0e47 2019-09-30 20:06:14
# 4037    53/7a3abcc0e3e011e990c345c3f76c0e47 2019-09-30 20:13:59
# 4038    52/10453ab0e3e111e990c345c3f76c0e47 2019-09-30 20:18:11
# 4039    55/556e0090e3e111e98246012e5e367d18 2019-09-30 20:20:07
# ...                                     ...                 ...
# 31468   53/ad91f5f0fc2e11e98246012e5e367d18 2019-10-31 18:34:14
# 31469   53/ba7c6340fc2e11e98246012e5e367d18 2019-10-31 18:34:35
# 31470   53/c50e3a90fc2e11e990c345c3f76c0e47 2019-10-31 18:34:53
# 31471   55/6b29e140fc2f11e990c345c3f76c0e47 2019-10-31 18:39:32
# 31472   54/6983e780fc3111e98246012e5e367d18 2019-10-31 18:53:48
#
# [27438 rows x 4 columns]

# %%
df['year'] = df['timestamped'].dt.year
df['month'] = df['timestamped'].dt.month
df['day'] = df['timestamped'].dt.day
df['hour'] = df['timestamped'].dt.hour
df['minute'] = df['timestamped'].dt.minute
df['second'] = df['timestamped'].dt.second
#df.loc[(df.second <= 20) & (df.second > 0), "second"] = 20
#df.loc[(df.second <= 40) & (df.second > 20), "second"] = 40
#df.loc[(df.second <= 59) & (df.second > 40), "second"] = 59
#df['second'] = np.where(df['second']<=30, 30, 59)
#df = df.drop(['second'], 1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['logtime'] = pd.to_datetime(df[['year', 'month', 'day', 'hour', 'minute','second']])
df = df.drop(['year', 'month', 'day', 'hour', 'minute','second','timestamped'], 1)
df = df.sort_values(by='logtime')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df#.to_csv('join2.csv')
df
# Out:
#       Date_Produced  Log_ID                                Item_Name  \
# 15239    2019-10-01   43100            Organic Rainbow Cherry Tomato
# 15240    2019-10-01   43101                       Organic Red Onions
# 15241    2019-10-01   43102                              Red Cabbage
# 15242    2019-10-01   43103  Paleo Friendly Roasted Red Bell Peppers
# 15243    2019-10-01   43104                         Cooked Red Beets
# ...             ...     ...                                      ...
# 4897     2019-10-31   69514                               Spring Mix
# 4898     2019-10-31   69515                             Baby Spinach
# 4899     2019-10-31   69516                                  Arugula
# 4900     2019-10-31   69517                          Romaine Lettuce
# 4901     2019-10-31   69518                                     Kale
#
#        Item_Type          PLU       Meal Action_Taken Action_Reason  Quantity  \
# 15239  Menu Item  46000016104  Breakfast       Served         Start   3.88014
# 15240  Menu Item  46000055881  Breakfast       Served         Start   2.93215
# 15241  Menu Item  46000055765  Breakfast       Served         Start   2.46918
# 15242  Menu Item  46000028993  Breakfast       Served         Start   2.91010
# 15243  Menu Item  46000007337  Breakfast       Served         Start   4.05651
# ...          ...          ...        ...          ...           ...       ...
# 4897   Menu Item  46000063050  Breakfast        Saved           End   3.74786
# 4898   Menu Item  46000055923  Breakfast        Saved           End   4.03446
# 4899   Menu Item  46000055714  Breakfast        Saved           End   1.65347
# 4900   Menu Item  46000055863  Breakfast        Saved           End   5.51156
# 4901   Menu Item  46000055842  Breakfast        Saved           End   1.34482
#
#        Pan_ID  ...  Unit Station Employee_Name Location_ID  Location   Served  \
# 15239     175  ...   Lbs      SB          None          53  Westford  2.03014
# 15240     175  ...   Lbs      SB          None          53  Westford  1.08215
# 15241     175  ...   Lbs      SB          None          53  Westford  0.61918
# 15242     175  ...   Lbs      SB          None          53  Westford  1.06010
# 15243     175  ...   Lbs      SB          None          53  Westford  2.20651
# ...       ...  ...   ...     ...           ...         ...       ...      ...
# 4897      110  ...   Lbs      SB          None          51    Dedham  0.00000
# 4898      110  ...   Lbs      SB          None          51    Dedham  0.00000
# 4899      111  ...   Lbs      SB          None          51    Dedham  0.00000
# 4900      110  ...   Lbs      SB          None          51    Dedham  0.00000
# 4901      110  ...   Lbs      SB          None          51    Dedham  0.00000
#
#          Saved     Sold  Shrink             logtime
# 15239  0.00000  2.03014     0.0 2019-10-01 05:18:13
# 15240  0.00000  1.08215     0.0 2019-10-01 05:19:07
# 15241  0.00000  0.61918     0.0 2019-10-01 05:34:51
# 15242  0.00000  1.06010     0.0 2019-10-01 05:35:15
# 15243  0.00000  2.20651     0.0 2019-10-01 05:36:35
# ...        ...      ...     ...                 ...
# 4897   3.15786 -3.15786     0.0 2019-10-31 21:54:26
# 4898   3.44446 -3.44446     0.0 2019-10-31 21:54:48
# 4899   1.30347 -1.30347     0.0 2019-10-31 21:56:35
# 4900   4.92156 -4.92156     0.0 2019-10-31 21:56:55
# 4901   0.75482 -0.75482     0.0 2019-10-31 21:57:14
#
# [26042 rows x 21 columns]

# %%
df53 = df[df.Location_ID==53].reset_index(drop=True)
df53#.to_csv('join1.csv')
# Out:
#      Date_Produced  Log_ID                                 Item_Name  \
# 0       2019-10-01   43100             Organic Rainbow Cherry Tomato
# 1       2019-10-01   43101                        Organic Red Onions
# 2       2019-10-01   43102                               Red Cabbage
# 3       2019-10-01   43103   Paleo Friendly Roasted Red Bell Peppers
# 4       2019-10-01   43104                          Cooked Red Beets
# ...            ...     ...                                       ...
# 7016    2019-10-31   69425                        Pumpkin Tortellini
# 7017    2019-10-31   69427                        Chicken Cacciatore
# 7018    2019-10-31   69428  Garlic Parm Pork Loin with Broccoli Rabe
# 7019    2019-10-31   69430                         Macaroni & Cheese
# 7020    2019-10-31   69431                     SHEPHERDS PIE BEEF HB
#
#       Item_Type          PLU       Meal Action_Taken  Action_Reason  Quantity  \
# 0     Menu Item  46000016104  Breakfast       Served          Start   3.88014
# 1     Menu Item  46000055881  Breakfast       Served          Start   2.93215
# 2     Menu Item  46000055765  Breakfast       Served          Start   2.46918
# 3     Menu Item  46000028993  Breakfast       Served          Start   2.91010
# 4     Menu Item  46000007337  Breakfast       Served          Start   4.05651
# ...         ...          ...        ...          ...            ...       ...
# 7016  Menu Item  46000029503  Breakfast    Discarded  Over Produced   4.27697
# 7017  Menu Item  46000005678  Breakfast    Discarded  Over Produced   6.08476
# 7018  Menu Item  46000029505  Breakfast    Discarded  Over Produced   2.29281
# 7019  Menu Item  46000060414  Breakfast    Discarded  Over Produced   8.13506
# 7020  Menu Item  46000022020  Breakfast    Discarded  Over Produced   3.32898
#
#       Pan_ID  ...  Unit Station Employee_Name Location_ID  Location   Served  \
# 0        175  ...   Lbs      SB          None          53  Westford  2.03014
# 1        175  ...   Lbs      SB          None          53  Westford  1.08215
# 2        175  ...   Lbs      SB          None          53  Westford  0.61918
# 3        175  ...   Lbs      SB          None          53  Westford  1.06010
# 4        175  ...   Lbs      SB          None          53  Westford  2.20651
# ...      ...  ...   ...     ...           ...         ...       ...      ...
# 7016     173  ...   Lbs      HB          None          53  Westford  0.00000
# 7017     173  ...   Lbs      HB          None          53  Westford  0.00000
# 7018     173  ...   Lbs      HB          None          53  Westford  0.00000
# 7019     173  ...   Lbs      HB          None          53  Westford  0.00000
# 7020     173  ...   Lbs      HB          None          53  Westford  0.00000
#
#       Saved     Sold   Shrink             logtime
# 0       0.0  2.03014  0.00000 2019-10-01 05:18:13
# 1       0.0  1.08215  0.00000 2019-10-01 05:19:07
# 2       0.0  0.61918  0.00000 2019-10-01 05:34:51
# 3       0.0  1.06010  0.00000 2019-10-01 05:35:15
# 4       0.0  2.20651  0.00000 2019-10-01 05:36:35
# ...     ...      ...      ...                 ...
# 7016    0.0 -2.73697  2.73697 2019-10-31 20:31:39
# 4       2019-10-01   43104                          Cooked Red Beets
# ...            ...     ...                                       ...
# 7016    2019-10-31   69425                        Pumpkin Tortellini
# 7017    2019-10-31   69427                        Chicken Cacciatore
# 7018    2019-10-31   69428  Garlic Parm Pork Loin with Broccoli Rabe
# 7019    2019-10-31   69430                         Macaroni & Cheese
# 7020    2019-10-31   69431                     SHEPHERDS PIE BEEF HB
#
#       Item_Type          PLU       Meal Action_Taken  Action_Reason  Quantity  \
# 0     Menu Item  46000016104  Breakfast       Served          Start   3.88014
# 1     Menu Item  46000055881  Breakfast       Served          Start   2.93215
# 2     Menu Item  46000055765  Breakfast       Served          Start   2.46918
# 3     Menu Item  46000028993  Breakfast       Served          Start   2.91010
# 4     Menu Item  46000007337  Breakfast       Served          Start   4.05651
# ...         ...          ...        ...          ...            ...       ...
# 7016  Menu Item  46000029503  Breakfast    Discarded  Over Produced   4.27697
# 7017  Menu Item  46000005678  Breakfast    Discarded  Over Produced   6.08476
# 7018  Menu Item  46000029505  Breakfast    Discarded  Over Produced   2.29281
# 7019  Menu Item  46000060414  Breakfast    Discarded  Over Produced   8.13506
# 7020  Menu Item  46000022020  Breakfast    Discarded  Over Produced   3.32898
#
#       Pan_ID  ...  Location_ID  Location   Served Saved     Sold   Shrink  \
# 0        175  ...           53  Westford  2.03014   0.0  2.03014  0.00000
# 1        175  ...           53  Westford  1.08215   0.0  1.08215  0.00000
# 2        175  ...           53  Westford  0.61918   0.0  0.61918  0.00000
# 3        175  ...           53  Westford  1.06010   0.0  1.06010  0.00000
# 4        175  ...           53  Westford  2.20651   0.0  2.20651  0.00000
# ...      ...  ...          ...       ...      ...   ...      ...      ...
# 7016     173  ...           53  Westford  0.00000   0.0 -2.73697  2.73697
# 7017     173  ...           53  Westford  0.00000   0.0 -4.54476  4.54476
# 7018     173  ...           53  Westford  0.00000   0.0 -0.75281  0.75281
# 7019     173  ...           53  Westford  0.00000   0.0 -6.59506  6.59506
# 7020     173  ...           53  Westford  0.00000   0.0 -1.78898  1.78898
#
#                  logtime  locationId                                imageId  \
# 0    2019-10-01 05:18:13         NaN                                    NaN
# 1    2019-10-01 05:19:07        53.0   a0044880-e42c-11e9-8246-012e5e367d18
# 2    2019-10-01 05:34:51         NaN                                    NaN
# 3    2019-10-01 05:35:15         NaN                                    NaN
# 4    2019-10-01 05:36:35         NaN                                    NaN
# ...                  ...         ...                                    ...
# 7016 2019-10-31 20:31:39         NaN                                    NaN
# 7017 2019-10-31 20:32:04         NaN                                    NaN
# 7018 2019-10-31 20:32:21         NaN                                    NaN
# 7019 2019-10-31 20:32:48         NaN                                    NaN
# 7020 2019-10-31 20:33:17         NaN                                    NaN
#
#                                   imageKey
# 0                                      NaN
# 1      53/a0044880e42c11e98246012e5e367d18
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 7016                                   NaN
# 7017                                   NaN
# 7018                                   NaN
# 7019                                   NaN
# 7020                                   NaN
#
# [7021 rows x 24 columns]

# %%
full.to_csv('oct53.csv')
